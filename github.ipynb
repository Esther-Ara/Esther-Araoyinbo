# %%
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Esther

# %%
os.chdir('C:\\Users\\Esther\\Downloads\Marketing Analytics Lab')

# %%
print(os.getcwd())
# Out:
# C:\Users\Esther\Downloads\Marketing Analytics Lab

# %%
# Import the NY weather dataset
stat = pd.read_csv('C:\\Users\\Esther\\Downloads\\Marketing Analytics Lab\\weather_data_nyc_centralpark_2016.csv')

# %%
stat
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# ..          ...                  ...                  ...
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 0                   38.0          0.00       0.0          0
# 1                   36.0          0.00       0.0          0
# 2                   40.0          0.00       0.0          0
# ...

# %%
# Number of Rows
len(stat)
# Out:
# 366

# %%
# explore column names
stat.columns
# Out:
# Index(['date', 'maximum temperature', 'minimum temperature',
#        'average temperature', 'precipitation', 'snow fall', 'snow depth'],
#       dtype='object')

# %%
#top rows and you can pass any number inside the ()
stat.head()
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %%
#bottom rows and you can pass any number inside the ()
stat.tail()
# Out:
#            date  maximum temperature  minimum temperature  \
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 361                 50.0             0         0          0
# 362                 37.0             0         0          0
# 363                 39.5          0.39         0          0
# 364                 36.5          0.01         T          0
# 365                 37.5             0         0          0

# %%
#info about the columns
stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 366 non-null    object
#  1   maximum temperature  366 non-null    int64
#  2   minimum temperature  366 non-null    int64
#  3   average temperature  366 non-null    float64
#  4   precipitation        366 non-null    object
#  5   snow fall            366 non-null    object
#  6   snow depth           366 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 20.1+ KB

# %%
# get stats on the columns on numeric data
stat.describe()
# Out:
#        maximum temperature  minimum temperature  average temperature
# count           366.000000           366.000000           366.000000
# mean             64.625683            49.806011            57.215847
# std              18.041787            16.570747            17.124760
# min              15.000000            -1.000000             7.000000
# 25%              50.000000            37.250000            44.000000
# 50%              64.500000            48.000000            55.750000
# 75%              81.000000            65.000000            73.500000
# max              96.000000            81.000000            88.500000

# %%
stat.describe().transpose()
# Out:
#                      count       mean        std   min    25%    50%   75%  \
# maximum temperature  366.0  64.625683  18.041787  15.0  50.00  64.50  81.0
# minimum temperature  366.0  49.806011  16.570747  -1.0  37.25  48.00  65.0
# average temperature  366.0  57.215847  17.124760   7.0  44.00  55.75  73.5
#
#                       max
# maximum temperature  96.0
# minimum temperature  81.0
# average temperature  88.5

# %%
#Rename columns of a dataframe
stat.head()
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %%
stat.columns
# Out:
# Index(['date', 'maximum temperature', 'minimum temperature',
#        'average temperature', 'precipitation', 'snow fall', 'snow depth'],
#       dtype='object')

# %%
stat.columns= ['Date', 'MaximumTemperature', 'MinimumTemperature',
       'AverageTemperature', 'Precipitation', 'Snowfall', 'Snowdepth']

# %%
stat.columns
# Out:
# Index(['Date', 'MaximumTemperature', 'MinimumTemperature',
#        'AverageTemperature', 'Precipitation', 'Snowfall', 'Snowdepth'],
#       dtype='object')

# %%
stat.head()
# Out:
#        Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0  1-1-2016                  42                  34                38.0
# 1  2-1-2016                  40                  32                36.0
# 2  3-1-2016                  45                  35                40.0
# 3  4-1-2016                  36                  14                25.0
# 4  5-1-2016                  29                  11                20.0
#
#   Precipitation Snowfall Snowdepth
# 0          0.00      0.0         0
# 1          0.00      0.0         0
# 2          0.00      0.0         0
# 3          0.00      0.0         0
# 4          0.00      0.0         0

# %%
#subset rows using slicing
stat[25:29]
# Out:
#          Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 25  26-1-2016                  48                  38                43.0
# 26  27-1-2016                  47                  34                40.5
# 27  28-1-2016                  42                  32                37.0
# 28  29-1-2016                  41                  30                35.5
#
#    Precipitation Snowfall Snowdepth
# 25          0.00      0.0        17
# 26             T      0.0         9
# 27          0.00      0.0         6
# 28          0.00      0.0         6

# %%
stat[:]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0      1-1-2016                  42                  34                38.0
# 1      2-1-2016                  40                  32                36.0
# 2      3-1-2016                  45                  35                40.0
# 3      4-1-2016                  36                  14                25.0
# 4      5-1-2016                  29                  11                20.0
# ..          ...                 ...                 ...                 ...
# 361  27-12-2016                  60                  40                50.0
# 362  28-12-2016                  40                  34                37.0
# 363  29-12-2016                  46                  33                39.5
# 364  30-12-2016                  40                  33                36.5
# 365  31-12-2016                  44                  31                37.5
#
#     Precipitation Snowfall Snowdepth
# ...

# %%
stat[:20]
# Out:
#          Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0    1-1-2016                  42                  34                38.0
# 1    2-1-2016                  40                  32                36.0
# 2    3-1-2016                  45                  35                40.0
# 3    4-1-2016                  36                  14                25.0
# 4    5-1-2016                  29                  11                20.0
# 5    6-1-2016                  41                  25                33.0
# 6    7-1-2016                  46                  31                38.5
# 7    8-1-2016                  46                  31                38.5
# 8    9-1-2016                  47                  40                43.5
# 9   10-1-2016                  59                  40                49.5
# 10  11-1-2016                  40                  26                33.0
# 11  12-1-2016                  44                  25                34.5
# ...

# %%
stat[100:]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 100   10-4-2016                  50                  31                40.5
# 101   11-4-2016                  65                  43                54.0
# 102   12-4-2016                  59                  45                52.0
# 103   13-4-2016                  58                  40                49.0
# 104   14-4-2016                  62                  43                52.5
# ..          ...                 ...                 ...                 ...
# 361  27-12-2016                  60                  40                50.0
# 362  28-12-2016                  40                  34                37.0
# 363  29-12-2016                  46                  33                39.5
# 364  30-12-2016                  40                  33                36.5
# 365  31-12-2016                  44                  31                37.5
#
#     Precipitation Snowfall Snowdepth
# ...

# %%
# Quick Exercise to reverse the dataframe
stat[::-1]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 365  31-12-2016                  44                  31                37.5
# 364  30-12-2016                  40                  33                36.5
# 363  29-12-2016                  46                  33                39.5
# 362  28-12-2016                  40                  34                37.0
# 361  27-12-2016                  60                  40                50.0
# ..          ...                 ...                 ...                 ...
# 4      5-1-2016                  29                  11                20.0
# 3      4-1-2016                  36                  14                25.0
# 2      3-1-2016                  45                  35                40.0
# 1      2-1-2016                  40                  32                36.0
# 0      1-1-2016                  42                  34                38.0
#
#     Precipitation Snowfall Snowdepth
# ...

# %%
# Quick Exercise get every 20th data point
stat[::20]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0      1-1-2016                  42                  34                38.0
# 20    21-1-2016                  36                  26                31.0
# 40    10-2-2016                  39                  31                35.0
# 60     1-3-2016                  52                  39                45.5
# 80    21-3-2016                  50                  32                41.0
# 100   10-4-2016                  50                  31                40.5
# 120   30-4-2016                  65                  46                55.5
# 140   20-5-2016                  76                  53                64.5
# 160    9-6-2016                  71                  54                62.5
# 180   29-6-2016                  83                  67                75.0
# 200   19-7-2016                  83                  73                78.0
# ...

# %%
#Subset columns
stat['MaximumTemperature'].head()
# Out:
# 0    42
# 1    40
# 2    45
# 3    36
# 4    29
# Name: MaximumTemperature, dtype: int64

# %%
# Subset two columns
stat[['MaximumTemperature', 'MinimumTemperature']].head()
# Out:
#    MaximumTemperature  MinimumTemperature
# 0                  42                  34
# 1                  40                  32
# 2                  45                  35
# 3                  36                  14
# 4                  29                  11

# %%
#Quick Access to the column important to remove the space from the column name
stat.MaximumTemperature
# Out:
# 0      42
# 1      40
# 2      45
# 3      36
# 4      29
#        ..
# 361    60
# 362    40
# 363    46
# 364    40
# 365    44
# Name: MaximumTemperature, Length: 366, dtype: int64

# %%
# Combine the two (rows and column) and the order does not matter

stat[25:29][['MaximumTemperature', 'MinimumTemperature']]
# Out:
#     MaximumTemperature  MinimumTemperature
# 25                  48                  38
# 26                  47                  34
# 27                  42                  32
# 28                  41                  30

# %%
#Mathematical operations
stat.head()
# Out:
#        Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0  1-1-2016                  42                  34                38.0
# 1  2-1-2016                  40                  32                36.0
# 2  3-1-2016                  45                  35                40.0
# 3  4-1-2016                  36                  14                25.0
# 4  5-1-2016                  29                  11                20.0
#
#   Precipitation Snowfall Snowdepth
# 0          0.00      0.0         0
# 1          0.00      0.0         0
# 2          0.00      0.0         0
# 3          0.00      0.0         0
# 4          0.00      0.0         0

# %%
# Create a Series object
result=stat.MinimumTemperature*stat.AverageTemperature

# %%
result.head()
# Out:
# 0    1292.0
# 1    1152.0
# 2    1400.0
# 3     350.0
# 4     220.0
# dtype: float64

# %%
# Create a new column
stat['MyCalc'] = stat.MinimumTemperature*stat.AverageTemperature

# %%
#Add the series as a column to the dataframe 
stat['MyCalc1'] = result

# %%
stat.head()
# Out:
#        Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0  1-1-2016                  42                  34                38.0
# 1  2-1-2016                  40                  32                36.0
# 2  3-1-2016                  45                  35                40.0
# 3  4-1-2016                  36                  14                25.0
# 4  5-1-2016                  29                  11                20.0
#
#   Precipitation Snowfall Snowdepth  MyCalc  MyCalc1
# 0          0.00      0.0         0  1292.0   1292.0
# 1          0.00      0.0         0  1152.0   1152.0
# 2          0.00      0.0         0  1400.0   1400.0
# 3          0.00      0.0         0   350.0    350.0
# 4          0.00      0.0         0   220.0    220.0

# %%
#Removing a column
stat.drop('MyCalc1', 1)
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0      1-1-2016                  42                  34                38.0
# 1      2-1-2016                  40                  32                36.0
# 2      3-1-2016                  45                  35                40.0
# 3      4-1-2016                  36                  14                25.0
# 4      5-1-2016                  29                  11                20.0
# ..          ...                 ...                 ...                 ...
# 361  27-12-2016                  60                  40                50.0
# 362  28-12-2016                  40                  34                37.0
# 363  29-12-2016                  46                  33                39.5
# 364  30-12-2016                  40                  33                36.5
# 365  31-12-2016                  44                  31                37.5
#
#     Precipitation Snowfall Snowdepth
# ...

# %%
stat.head()
# Out:
#        Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0  1-1-2016                  42                  34                38.0
# 1  2-1-2016                  40                  32                36.0
# 2  3-1-2016                  45                  35                40.0
# 3  4-1-2016                  36                  14                25.0
# 4  5-1-2016                  29                  11                20.0
#
#   Precipitation Snowfall Snowdepth  MyCalc  MyCalc1
# 0          0.00      0.0         0  1292.0   1292.0
# 1          0.00      0.0         0  1152.0   1152.0
# 2          0.00      0.0         0  1400.0   1400.0
# 3          0.00      0.0         0   350.0    350.0
# 4          0.00      0.0         0   220.0    220.0

# %% [markdown]
# # What Happened?

# %%
stat=stat.drop('MyCalc', 1)

# %%
stat.head()
# Out:
#        Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0  1-1-2016                  42                  34                38.0
# 1  2-1-2016                  40                  32                36.0
# 2  3-1-2016                  45                  35                40.0
# 3  4-1-2016                  36                  14                25.0
# 4  5-1-2016                  29                  11                20.0
#
#   Precipitation Snowfall Snowdepth  MyCalc1
# 0          0.00      0.0         0   1292.0
# 1          0.00      0.0         0   1152.0
# 2          0.00      0.0         0   1400.0
# 3          0.00      0.0         0    350.0
# 4          0.00      0.0         0    220.0

# %%
#Filtering a Dataframe by rows
stat.MaximumTemperature <40
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: MaximumTemperature, Length: 366, dtype: bool

# %%
# Store the filtered results
Filter = stat.MaximumTemperature <40

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: MaximumTemperature, Length: 366, dtype: bool

# %%
# To see the filtered output you need to call filtered results as part of the dataframe inside the square brackets
stat[Filter]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 3      4-1-2016                  36                  14                25.0
# 4      5-1-2016                  29                  11                20.0
# 12    13-1-2016                  30                  22                26.0
# 13    14-1-2016                  38                  22                30.0
# 17    18-1-2016                  31                  18                24.5
# 18    19-1-2016                  28                  16                22.0
# 19    20-1-2016                  37                  27                32.0
# 20    21-1-2016                  36                  26                31.0
# 21    22-1-2016                  30                  21                25.5
# 22    23-1-2016                  27                  24                25.5
# 23    24-1-2016                  35                  20                27.5
# ...

# %%
#Filtering a Dataframe by rows
Filter2 = stat.AverageTemperature <25

# %%
Filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: AverageTemperature, Length: 366, dtype: bool

# %%
# To see the filtered output you need to call filtered results as part of the dataframe inside the square brackets
stat[Filter2]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 4      5-1-2016                  29                  11                20.0
# 17    18-1-2016                  31                  18                24.5
# 18    19-1-2016                  28                  16                22.0
# 41    11-2-2016                  31                  18                24.5
# 42    12-2-2016                  27                  15                21.0
# 43    13-2-2016                  22                   6                14.0
# 44    14-2-2016                  15                  -1                 7.0
# 45    15-2-2016                  35                  13                24.0
# 350  16-12-2016                  27                  17                22.0
#
#     Precipitation Snowfall Snowdepth  MyCalc1
# 4            0.00      0.0         0    220.0
# 17              T        T         T    441.0
# 18           0.00      0.0         T    352.0
# ...

# %%
# Another way of filtering
stat[stat.AverageTemperature <25]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 4      5-1-2016                  29                  11                20.0
# 17    18-1-2016                  31                  18                24.5
# 18    19-1-2016                  28                  16                22.0
# 41    11-2-2016                  31                  18                24.5
# 42    12-2-2016                  27                  15                21.0
# 43    13-2-2016                  22                   6                14.0
# 44    14-2-2016                  15                  -1                 7.0
# 45    15-2-2016                  35                  13                24.0
# 350  16-12-2016                  27                  17                22.0
#
#     Precipitation Snowfall Snowdepth  MyCalc1
# 4            0.00      0.0         0    220.0
# 17              T        T         T    441.0
# 18           0.00      0.0         T    352.0
# ...

# %%
#Combine filters using &
Filter & Filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Length: 366, dtype: bool

# %%
stat [Filter & Filter2]
# Out:
#            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 4      5-1-2016                  29                  11                20.0
# 17    18-1-2016                  31                  18                24.5
# 18    19-1-2016                  28                  16                22.0
# 41    11-2-2016                  31                  18                24.5
# 42    12-2-2016                  27                  15                21.0
# 43    13-2-2016                  22                   6                14.0
# 44    14-2-2016                  15                  -1                 7.0
# 45    15-2-2016                  35                  13                24.0
# 350  16-12-2016                  27                  17                22.0
#
#     Precipitation Snowfall Snowdepth  MyCalc1
# 4            0.00      0.0         0    220.0
# 17              T        T         T    441.0
# 18           0.00      0.0         T    352.0
# ...

# %%
#Use unique
stat.Date.unique()
# Out:
# array(['1-1-2016', '2-1-2016', '3-1-2016', '4-1-2016', '5-1-2016',
#        '6-1-2016', '7-1-2016', '8-1-2016', '9-1-2016', '10-1-2016',
#        '11-1-2016', '12-1-2016', '13-1-2016', '14-1-2016', '15-1-2016',
#        '16-1-2016', '17-1-2016', '18-1-2016', '19-1-2016', '20-1-2016',
#        '21-1-2016', '22-1-2016', '23-1-2016', '24-1-2016', '25-1-2016',
#        '26-1-2016', '27-1-2016', '28-1-2016', '29-1-2016', '30-1-2016',
#        '31-1-2016', '1-2-2016', '2-2-2016', '3-2-2016', '4-2-2016',
#        '5-2-2016', '6-2-2016', '7-2-2016', '8-2-2016', '9-2-2016',
#        '10-2-2016', '11-2-2016', '12-2-2016', '13-2-2016', '14-2-2016',
#        '15-2-2016', '16-2-2016', '17-2-2016', '18-2-2016', '19-2-2016',
#        '20-2-2016', '21-2-2016', '22-2-2016', '23-2-2016', '24-2-2016',
#        '25-2-2016', '26-2-2016', '27-2-2016', '28-2-2016', '29-2-2016',
#        '1-3-2016', '2-3-2016', '3-3-2016', '4-3-2016', '5-3-2016',
# ...

# %%
#Accessing individual elements
stat.head()
# Out:
#        Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0  1-1-2016                  42                  34                38.0
# 1  2-1-2016                  40                  32                36.0
# 2  3-1-2016                  45                  35                40.0
# 3  4-1-2016                  36                  14                25.0
# 4  5-1-2016                  29                  11                20.0
#
#   Precipitation Snowfall Snowdepth  MyCalc1
# 0          0.00      0.0         0   1292.0
# 1          0.00      0.0         0   1152.0
# 2          0.00      0.0         0   1400.0
# 3          0.00      0.0         0    350.0
# 4          0.00      0.0         0    220.0

# %%
#.iat for integers
stat.iat[4, 4]
# Out:
# '0.00'

# %%
stat.iat[0, 0]
# Out:
# '1-1-2016'

# %%
# .at for labels
stat.at [1, 'MinimumTemperature']
# Out:
# 32

# %% [markdown]
# # Introduction to Seaborn

# %%
# Import the required libraries and plots are created in Jupyter notebook
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
stat.head
# Out:
# <bound method NDFrame.head of            Date  MaximumTemperature  MinimumTemperature  AverageTemperature  \
# 0      1-1-2016                  42                  34                38.0
# 1      2-1-2016                  40                  32                36.0
# 2      3-1-2016                  45                  35                40.0
# 3      4-1-2016                  36                  14                25.0
# 4      5-1-2016                  29                  11                20.0
# ..          ...                 ...                 ...                 ...
# 361  27-12-2016                  60                  40                50.0
# 362  28-12-2016                  40                  34                37.0
# 363  29-12-2016                  46                  33                39.5
# 364  30-12-2016                  40                  33                36.5
# 365  31-12-2016                  44                  31                37.5
#
# ...

# %%
#Distribution
vis1= sns.distplot(stat["MaximumTemperature"])
